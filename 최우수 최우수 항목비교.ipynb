# %%
#라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1분기 데이터 불러오기
half1=pd.read_excel('지그재그 카페24 1분기 2분기 .xlsx',sheet_name='Sheet1')
half1.head()
# Out:
#                  주문일시                        상품명       구매자명ID   유입경로 클릭카테고리
# 0 2020-07-28 00:01:25  [La belle rose]마린 브이 여름니트  김지애wldo****  지그재그앱   지그재그
# 1 2020-07-28 00:01:25  [La belle rose]마린 브이 여름니트  김지애wldo****  지그재그앱   지그재그
# 2 2020-07-28 00:03:14    [La belle rose]프롬 퍼프원피스  최혜리hyer****  지그재그앱   지그재그
# 3 2020-07-28 00:03:14    [La belle rose]프롬 퍼프원피스  최혜리hyer****  지그재그앱   지그재그
# 4 2020-07-28 00:12:32                   구미 버튼린넨티  박효진gywl****  지그재그앱   지그재그

# %%
best=pd.read_excel('최우수최우수 고객명단.xlsx')
best.rename(columns={'주문자ID번호':'구매자명ID'},inplace=True)
best.head()
# Out:
#                     구매자명ID
# 0     sul2009010-5688-7729
# 1            010-9895-5090
# 2  thwlsdid12010-3117-9853
# 3        wood010-9599-9787
# 4   maxnme127010-3431-7199

# %%
data1=pd.merge(best,half1,how='inner',on=['구매자명ID'])

# %%
half1.shape, best.shape,data1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5673573a340a> in <module>
# ----> 1 half1.shape, best.shape,dat1.shape
#
# NameError: name 'dat1' is not defined

# %%
data1
# Out:
#                      구매자명ID                주문일시  \
# 0      sul2009010-5688-7729 2020-08-03 09:43:00
# 1      sul2009010-5688-7729 2020-08-03 09:43:00
# 2      sul2009010-5688-7729 2020-08-03 09:43:00
# 3      sul2009010-5688-7729 2020-08-03 09:43:00
# 4      sul2009010-5688-7729 2020-08-03 09:43:00
# ...                     ...                 ...
# 10201         010-5113-4316 2020-08-26 20:26:00
# 10202         010-5113-4316 2021-01-03 21:00:00
# 10203         010-5113-4316 2021-01-03 21:00:00
# 10204         010-5113-4316 2021-01-18 14:21:00
# 10205         010-5113-4316 2021-01-18 14:21:00
#
#                                       상품명    유입경로 클릭카테고리
# 0                               미미 라운드반팔티    모바일웹     상의
# 1                              스코코 언발 숏팬츠    모바일웹     하의
# 2                                구미 버튼린넨티    모바일웹   메인화면
# 3                    [DAYONE LABEL]로티 숏팬츠    모바일웹     하의
# 4                                  루안 헤어핀    모바일웹   메인화면
# ...
